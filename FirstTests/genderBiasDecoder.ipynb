# %%
import pandas as pd

df = pd.read_csv('./resumes.csv', delimiter=';')
df.head()
# Out:
#       name  gender                                              tekst  \
# 0      Amy  female  PROFILE\nFund accountant with nearly 2 years o...
# 1      Ben    male  Fund Accoutant\tSep 2016 - Present\n(Citco Fun...
# 2   Carrie  female  Professional Experience\nCitco Fund Services (...
# 3  Dickson    male  PROFESSIONAL EXPERIENCE\t\n\nConifer Financial...
# 4  Edwardo    male  QUALIFICATION SUMMARY\n\n•\tResults-driven ach...
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.columns = ['name', 'gender', 'text', 'unnamed']
df.head()
# Out:
#       name  gender                                               text unnamed
# 0      Amy  female  PROFILE\nFund accountant with nearly 2 years o...     NaN
# 1      Ben    male  Fund Accoutant\tSep 2016 - Present\n(Citco Fun...     NaN
# 2   Carrie  female  Professional Experience\nCitco Fund Services (...     NaN
# 3  Dickson    male  PROFESSIONAL EXPERIENCE\t\n\nConifer Financial...     NaN
# 4  Edwardo    male  QUALIFICATION SUMMARY\n\n•\tResults-driven ach...     NaN

# %%
df.drop(['unnamed'], axis=1, inplace=True)
df.head()
# Out:
#       name  gender                                               text
# 0      Amy  female  PROFILE\nFund accountant with nearly 2 years o...
# 1      Ben    male  Fund Accoutant\tSep 2016 - Present\n(Citco Fun...
# 2   Carrie  female  Professional Experience\nCitco Fund Services (...
# 3  Dickson    male  PROFESSIONAL EXPERIENCE\t\n\nConifer Financial...
# 4  Edwardo    male  QUALIFICATION SUMMARY\n\n•\tResults-driven ach...

# %%
df2 = pd.read_csv('./resumes4.csv', delimiter=';')
df2.columns = ['name', 'gender', 'text']
df2
# Out:
#         name gender                                               text
# 0     Steven   male  SEASONED BANKING AND FINANCE OPERATIONS PROFES...
# 1      Frank   male  EXPERIENCE\nSenior Financial Accountant\n6 201...
# 2     Dexter   male  Advising on private equity investment activiti...
# 3     Martin   male  Career Objective: To contribute my over 20 yea...
# 4    Vincent   male  EDUCATION\nAug 12 to Dec 16\nAug 14 to Dec 14\...
# 5   Jonathan   male  EDUCATION\nNational University of Singapore\nM...
# 6      Eddie   male  Education\n2016\n2017\n2012\n20 14\nHong Kong ...
# 7       Chen   male  SUMMARY\nTrader with accounting and audit back...
# 8    Spencer   male  EDUCATION\nChina Europe International Business...
# 9   Benjamin   male  SUMMARY\nOver 4 years industry experience with...
# 10   Gabriel   male  To secure a position in a progressive work env...
# 11   Michael   male  PROFESSIONAL EXPERIENCE\n2011.9 - Present | SA...
# ...

# %%
df = df.append(df2, ignore_index = True) 
df
# Out:
#         name  gender                                               text
# 0        Amy  female  PROFILE\nFund accountant with nearly 2 years o...
# 1        Ben    male  Fund Accoutant\tSep 2016 - Present\n(Citco Fun...
# 2     Carrie  female  Professional Experience\nCitco Fund Services (...
# 3    Dickson    male  PROFESSIONAL EXPERIENCE\t\n\nConifer Financial...
# 4    Edwardo    male  QUALIFICATION SUMMARY\n\n•\tResults-driven ach...
# ..       ...     ...                                                ...
# 329   Darryl    male  CAREER OBJECTIVE\nTo secure a challenging posi...
# 330  Jeremie    male  OBJECTIVES\nBeing a versatile individual in ta...
# 331    Ricky    male  SUMMARY OF QUALIFICATIONS\n\n•\tSolid working ...
# 332  Wilfred    male  HSBC, (On-boarding & Customer Due diligence An...
# 333   Dennis    male  Work Experience\nJuly 2015 - Present\nHSZ GROU...
#
# [334 rows x 3 columns]

# %%
df.to_csv('resumes3.csv', index=False)
